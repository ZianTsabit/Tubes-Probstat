# %% [markdown]
# # Test korelasi
#
# ### Tentukan apakah setiap kolom non-target berkorelasi dengan kolom target, dengan menggambarkan juga scatter plot nya. Gunakan correlation test.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('water_potability.csv', index_col=0)
df.head()
# Out:
#                        pH  Hardness    Solids  Chloramines   Sulfate  \
# pH               1.000000  0.108959 -0.085582    -0.024767  0.011028
# Hardness         0.108959  1.000000 -0.053282    -0.022684 -0.108509
# Solids          -0.085582 -0.053282  1.000000    -0.051933 -0.164106
# Chloramines     -0.024767 -0.022684 -0.051933     1.000000  0.006248
# Sulfate          0.011028 -0.108509 -0.164106     0.006248  1.000000
# Conductivity     0.015089  0.011778 -0.007045    -0.028300 -0.016600
# OrganicCarbon    0.028285  0.013219 -0.005290    -0.023806  0.026823
# Trihalomethanes  0.018302 -0.015400 -0.015729     0.014990 -0.023355
# Turbidity       -0.035416 -0.034813  0.018569     0.013132 -0.010129
# Potability       0.015475 -0.001463  0.038977     0.020779 -0.015703
#
#                  Conductivity  OrganicCarbon  Trihalomethanes  Turbidity  \
# pH                   0.015089       0.028285         0.018302  -0.035416
# Hardness             0.011778       0.013219        -0.015400  -0.034813
# Solids              -0.007045      -0.005290        -0.015729   0.018569
# Chloramines         -0.028300      -0.023806         0.014990   0.013132
# Sulfate             -0.016600       0.026823        -0.023355  -0.010129
# Conductivity         1.000000       0.015739         0.004879   0.012133
# OrganicCarbon        0.015739       1.000000        -0.005666  -0.015388
# Trihalomethanes      0.004879      -0.005666         1.000000  -0.020504
# Turbidity            0.012133      -0.015388        -0.020504   1.000000
# Potability          -0.016257      -0.015488         0.009237   0.022331
#
#                  Potability
# pH                 0.015475
# Hardness          -0.001463
# Solids             0.038977
# Chloramines        0.020779
# Sulfate           -0.015703
# Conductivity      -0.016257
# OrganicCarbon     -0.015488
# Trihalomethanes    0.009237
# Turbidity          0.022331
# Potability         1.000000

# %%
col_numeric = [
    'pH', 
    'Hardness', 
    'Solids', 
    'Chloramines', 
    'Sulfate', 
    'Conductivity', 
    'OrganicCarbon', 
    'Trihalomethanes', 
    'Turbidity'
]

df_potability = df['Potability']

for i in col_numeric:
    corr = df[i].corr(df_potability)
    print(corr)
# Out:
# 0.01547509440843346
# -0.0014631528959479338
# 0.03897657818173466
# 0.020778921840524076
# -0.015703164419273802
# -0.01625712011137705
# -0.015488461910747266
# 0.009236711064713014
# 0.022331042640622658
